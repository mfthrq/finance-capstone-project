# %% [markdown]
# Finance Data - Capstone Project
#
# - Bank of America
# - CitiGroup
# - Goldman Sachs
# - JPMorgan Chase
# - Morgan Stanley
# - Wells Fargo

# %%
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import datetime
import yfinance as yf
# %matplotlib inline

# %%
start_date = datetime.datetime(2006, 1, 1)
end_date = datetime.datetime(2016, 1, 31)

# Bank of America
bac = yf.download('BAC', start=start_date, end=end_date)

# Citigroup
c = yf.download('C', start=start_date, end=end_date)

# Goldman Sachs
gs = yf.download('GS', start=start_date, end=end_date)

jpm = yf.download('JPM', start=start_date, end=end_date)

ms =  yf.download('MS', start=start_date, end=end_date)

wfc = yf.download('WFC', start=start_date, end=end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
bac.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2006-01-03  46.919998  47.180000  46.150002  47.080002  32.695660  16296700
# 2006-01-04  47.000000  47.240002  46.450001  46.580002  32.348434  17757900
# 2006-01-05  46.580002  46.830002  46.320000  46.639999  32.390099  14970700
# 2006-01-06  46.799999  46.910000  46.349998  46.570000  32.341488  12599800
# 2006-01-09  46.720001  46.970001  46.360001  46.599998  32.362324  15619400

# %%
c.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2006-01-03  490.000000  493.799988  481.100006  492.899994  346.774353
# 2006-01-04  488.600006  491.000000  483.500000  483.799988  340.372101
# 2006-01-05  484.399994  487.799988  484.000000  486.200012  342.060638
# 2006-01-06  488.799988  489.000000  482.000000  486.200012  342.060638
# 2006-01-09  486.000000  487.399994  483.000000  483.899994  340.442444
#
#              Volume
# Date
# 2006-01-03  1537600
# 2006-01-04  1870960
# 2006-01-05  1143160
# 2006-01-06  1370210
# 2006-01-09  1680740

# %%
gs.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2006-01-03  126.699997  129.440002  124.230003  128.869995   99.715446
# 2006-01-04  127.349998  128.910004  126.379997  127.089996   98.338165
# 2006-01-05  126.000000  127.320000  125.610001  127.040001   98.299492
# 2006-01-06  127.290001  129.250000  127.290001  128.839996   99.692253
# 2006-01-09  128.500000  130.619995  128.000000  130.389999  100.891632
#
#              Volume
# Date
# 2006-01-03  6188700
# 2006-01-04  4861600
# 2006-01-05  3717400
# 2006-01-06  4319600
# 2006-01-09  4723500

# %%
jpm.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2006-01-03  39.830002  40.360001  39.299999  40.189999  25.305477  12838600
# 2006-01-04  39.779999  40.139999  39.419998  39.619999  25.159420  13491500
# 2006-01-05  39.610001  39.810001  39.500000  39.740002  25.235632   8109400
# 2006-01-06  39.919998  40.240002  39.549999  40.020000  25.413425   7966900
# 2006-01-09  39.880001  40.720001  39.880001  40.669998  25.826181  16575200

# %%
ms.head()
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2006-01-03  57.169998  58.490002  56.740002  58.310001  34.310368  5377000
# 2006-01-04  58.700001  59.279999  58.349998  58.349998  34.333889  7977800
# 2006-01-05  58.549999  58.590000  58.020000  58.509998  34.428017  5778000
# 2006-01-06  58.770000  58.849998  58.049999  58.570000  34.463341  6889800
# 2006-01-09  58.630001  59.290001  58.619999  59.189999  34.828152  4144500

# %%
wfc.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2006-01-03  31.600000  31.975000  31.195000  31.900000  19.695114  11016400
# 2006-01-04  31.799999  31.820000  31.365000  31.530001  19.466675  10870000
# 2006-01-05  31.500000  31.555000  31.309999  31.495001  19.445070  10158000
# 2006-01-06  31.580000  31.775000  31.385000  31.680000  19.559286   8403800
# 2006-01-09  31.674999  31.825001  31.555000  31.674999  19.556202   5619600

# %% [markdown]
# List of ticker (stock code) symbols (as strings)

# %%
tickers = ['bac', 'c', 'gs', 'jpm', 'ms', 'wfc']

# %% [markdown]
# Concate tickers with pd

# %%
bank_stocks = pd.concat([bac, c, gs, jpm, ms, wfc], axis = 1, keys=tickers)
bank_stocks.head()
# Out:
#                   bac                                                        \
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2006-01-03  46.919998  47.180000  46.150002  47.080002  32.695660  16296700
# 2006-01-04  47.000000  47.240002  46.450001  46.580002  32.348434  17757900
# 2006-01-05  46.580002  46.830002  46.320000  46.639999  32.390099  14970700
# 2006-01-06  46.799999  46.910000  46.349998  46.570000  32.341488  12599800
# 2006-01-09  46.720001  46.970001  46.360001  46.599998  32.362324  15619400
#
#                      c                                      ...         ms  \
#                   Open        High         Low       Close  ...        Low
# Date                                                        ...
# 2006-01-03  490.000000  493.799988  481.100006  492.899994  ...  56.740002
# 2006-01-04  488.600006  491.000000  483.500000  483.799988  ...  58.349998
# ...

# %%
bank_stocks.columns.names = ['Bank Stocks', 'Stock Info']
bank_stocks.head()
# Out:
# Bank Stocks        bac                                                        \
# Stock Info        Open       High        Low      Close  Adj Close    Volume
# Date
# 2006-01-03   46.919998  47.180000  46.150002  47.080002  32.695660  16296700
# 2006-01-04   47.000000  47.240002  46.450001  46.580002  32.348434  17757900
# 2006-01-05   46.580002  46.830002  46.320000  46.639999  32.390099  14970700
# 2006-01-06   46.799999  46.910000  46.349998  46.570000  32.341488  12599800
# 2006-01-09   46.720001  46.970001  46.360001  46.599998  32.362324  15619400
#
# Bank Stocks           c                                      ...         ms  \
# Stock Info         Open        High         Low       Close  ...        Low
# Date                                                         ...
# 2006-01-03   490.000000  493.799988  481.100006  492.899994  ...  56.740002
# 2006-01-04   488.600006  491.000000  483.500000  483.799988  ...  58.349998
# ...

# %% [markdown]
# Exploratory Data Analysis

# %%
# for tick in tickers:
#     print(tick, "=", bank_stocks[tick]['Close'].max())
# Out:
# bac = 54.900001525878906
# c = 564.0999755859375
# gs = 247.9199981689453
# jpm = 70.08000183105469
# ms = 89.30000305175781
# wfc = 58.52000045776367

# %% [markdown]
# Use .xs method

# %%
bank_stocks.xs(key='Close', axis=1, level='Stock Info').max()
# Out:
# Bank Stocks
# bac     54.900002
# c      564.099976
# gs     247.919998
# jpm     70.080002
# ms      89.300003
# wfc     58.520000
# dtype: float64

# %%
returns = pd.DataFrame()

# %%
for tick in tickers:
    returns[tick+ ' Return'] = bank_stocks[tick]['Close'].pct_change()

# %%
returns.head()
# Out:
#             bac Return  c Return  gs Return  jpm Return  ms Return  wfc Return
# Date
# 2006-01-03         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-01-04   -0.010620 -0.018462  -0.013812   -0.014183   0.000686   -0.011599
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029   0.002742   -0.001110
# 2006-01-06   -0.001501  0.000000   0.014169    0.007046   0.001025    0.005874
# 2006-01-09    0.000644 -0.004731   0.012030    0.016242   0.010586   -0.000158

# %%
import seaborn as sns

# %%
sns.pairplot(returns[1:])
